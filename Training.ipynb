# %%
import pickle

# %%
x = pickle.load(open('x.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))

# %%
x = x/2

# %%
x.shape
# Out:
# (13, 100, 100, 3)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(128, input_shape = x.shape[1:], activation = 'relu'))

model.add(Dense(2, activation = 'softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x, y, epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 0s 200ms/step - loss: 4.4412 - accuracy: 0.1818 - val_loss: 383.8287 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 0s 32ms/step - loss: 117.5764 - accuracy: 0.5455 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/5
# 1/1 [==============================] - 0s 28ms/step - loss: 163.3727 - accuracy: 0.4545 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/5
# 1/1 [==============================] - 0s 29ms/step - loss: 51.4945 - accuracy: 0.4545 - val_loss: 25.2322 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 84.4370 - val_accuracy: 0.0000e+00
